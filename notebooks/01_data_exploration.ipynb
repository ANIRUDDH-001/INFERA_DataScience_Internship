# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
# Step 1: Get all climate CSV files
climate_files = glob.glob("../data/raw/dataset_1/*_Climate.csv")

# %%
# Step 2: Load files with encoding fallback
climate_dataframes = []

for file in climate_files:
    try:
        df = pd.read_csv(file)
    except UnicodeDecodeError:
        df = pd.read_csv(file, encoding='ISO-8859-1')
    climate_dataframes.append(df)

# %%
# Step 3: Concatenate into one DataFrame
climate_data = pd.concat(climate_dataframes, ignore_index=True)

# %%
# Step 4: Convert 'Date' column to datetime
climate_data['Date'] = pd.to_datetime(climate_data['Date'], errors='coerce')
# Out:
# C:\Users\ANIRU\AppData\Local\Temp\ipykernel_24076\1072981421.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   climate_data['Date'] = pd.to_datetime(climate_data['Date'], errors='coerce')

# %%
# Step 5: Preview the loaded data
climate_data.head()
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0 2024-01-01                      12.6                      23.2
# 1 2024-02-01                      16.9                      24.7
# 2 2024-03-01                      17.8                      26.9
# 3 2024-04-01                      17.8                      21.9
# 4 2024-05-01                      15.9                      28.9
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               7.2              11.4
# 1            0.0               6.8               3.3
# 2           17.8               5.8               3.6
# 3            1.0               4.0               3.2
# 4            0.0               4.8               5.7
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             SSW                               31.0
# 1                              SW                               41.0
# 2                               S                               30.0
# 3                             SSW                               33.0
# 4                              SE                               31.0
#
#   Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                     14:35                  17.6  ...
# 1                     14:23                  19.6  ...
# 2                     21:34                  19.3  ...
# 3                     17:46                  18.3  ...
# 4                     18:48                  19.9  ...
#
#    9am cloud amount (oktas)  9am wind direction 9am wind speed (km/h)  \
# 0                         7                  SW                     4
# 1                         7                 NNW                     7
# 2                         7                                      Calm
# 3                         8                 SSW                    11
# 4                         7                  NW                     6
#
#   9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                 1021.7                  22.5                         60
# 1                 1017.4                  21.9                         77
# 2                 1015.4                  26.3                         70
# 3                 1020.1                  20.3                         71
# 4                 1021.2                  26.4                         58
#
#    3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 0                       7.0                 SSW                    13
# 1                       8.0                  SW                    15
# 2                       7.0                   S                     6
# 3                       7.0                 SSW                    15
# 4                       6.0                 SSW                     9
#
#   3pm MSL pressure (hPa)
# 0                 1017.7
# 1                 1014.8
# 2                 1013.3
# 3                 1019.8
# 4                 1019.0
#
# [5 rows x 21 columns]

# %%
climate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               306 non-null    datetime64[ns]
#  1   Minimum temperature (°C)           304 non-null    float64
#  2   Maximum temperature (°C)           304 non-null    float64
#  3   Rainfall (mm)                      304 non-null    float64
#  4   Evaporation (mm)                   306 non-null    float64
#  5   Sunshine (hours)                   306 non-null    float64
#  6   Direction of maximum wind gust     301 non-null    object
#  7   Speed of maximum wind gust (km/h)  301 non-null    float64
#  8   Time of maximum wind gust          301 non-null    object
#  9   9am Temperature (°C)               306 non-null    float64
#  10  9am relative humidity (%)          306 non-null    int64
#  11  9am cloud amount (oktas)           306 non-null    int64
#  12  9am wind direction                 306 non-null    object
#  13  9am wind speed (km/h)              306 non-null    object
#  14  9am MSL pressure (hPa)             306 non-null    float64
#  15  3pm Temperature (°C)               306 non-null    float64
#  16  3pm relative humidity (%)          306 non-null    int64
#  17  3pm cloud amount (oktas)           305 non-null    float64
#  18  3pm wind direction                 306 non-null    object
#  19  3pm wind speed (km/h)              306 non-null    object
#  20  3pm MSL pressure (hPa)             306 non-null    float64
# dtypes: datetime64[ns](1), float64(11), int64(3), object(6)
# memory usage: 50.3+ KB

# %%
climate_data.isnull().sum()
# Out:
# Date                                 0
# Minimum temperature (°C)             2
# Maximum temperature (°C)             2
# Rainfall (mm)                        2
# Evaporation (mm)                     0
# Sunshine (hours)                     0
# Direction of maximum wind gust       5
# Speed of maximum wind gust (km/h)    5
# Time of maximum wind gust            5
# 9am Temperature (°C)                 0
# 9am relative humidity (%)            0
# 9am cloud amount (oktas)             0
# 9am wind direction                   0
# 9am wind speed (km/h)                0
# 9am MSL pressure (hPa)               0
# 3pm Temperature (°C)                 0
# 3pm relative humidity (%)            0
# 3pm cloud amount (oktas)             1
# 3pm wind direction                   0
# 3pm wind speed (km/h)                0
# 3pm MSL pressure (hPa)               0
# dtype: int64
